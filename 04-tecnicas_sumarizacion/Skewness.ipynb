# %%
import pandas as pd
 
 
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/titanic.csv"
df = pd.read_csv(url)

# %%
#Skew devuelve la asimetria no sesgada sobre el eje especifico
print(df["Age"].skew())
# Out:
# 0.38910778230082704
